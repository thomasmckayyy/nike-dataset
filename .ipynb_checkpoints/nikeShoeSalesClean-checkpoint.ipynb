# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import the dataset
nikeSet = pd.read_csv('../nike_shoes_sales.csv')
nikeSet.head(20)
#Already looking at the set we can get rid of unneccessary columns
# Out:
#                       product_name  product_id  listing_price  sale_price  \
# 0   Nike Air Force 1 '07 Essential  CJ1646-600              0        7495
# 1             Nike Air Force 1 '07  CT4328-101              0        7495
# 2     Nike Air Force 1 Sage Low LX  CI3482-200              0        9995
# 3              Nike Air Max Dia SE  CD0479-200              0        9995
# 4              Nike Air Max Verona  CZ6156-101              0        9995
# 5               Nike Free Metcon 3  CJ6314-146              0        9995
# 6                  NikeCourt Blanc  CI0808-100              0        5995
# 7               Nike Free Metcon 3  CJ0861-017              0        9995
# 8        Nike Zoom Pegasus Turbo 2  AT8242-009              0       15995
# 9       Nike Air Max 270 React ENG  CK2595-500              0       14995
# 10                 Nike Air Max 90  CD0490-104              0        9995
# 11            Nike Air Force 1 '07  315115-112              0        7495
# 12           Jordan Air Max 200 XX  AV5186-101              0       10495
# 13                Nike SuperRep Go  CJ0860-668              0        7995
# 14     Nike Air VaporMax Flyknit 3  AJ6910-009              0       16995
# 15          Nike Air Zoom SuperRep  BQ7043-668              0        9995
# 16      Nike Air Max 270 React ENG  CK2608-100              0       14995
# 17                 Nike Air Max 97  921733-104              0       16995
# 18            Nike Air Force 1 '07  CJ1379-001              0        7995
# 19      Nike Court Vintage Premium  CT1726-100              0        5495
#
#     discount brand                                        description  rating  \
# 0          0  Nike  Let your shoe game shimmer in the Nike Air For...     0.0
# 1          0  Nike  The legend lives on in the Nike Air Force 1 '0...     0.0
# 2          0  Nike  Taking both height and craft to new levels, th...     0.0
# 3          0  Nike  Designed for a woman's foot, the Nike Air Max ...     0.0
# 4          0  Nike  Pass on the good vibes in the Nike Air Max Ver...     0.0
# 5          0  Nike  The Nike Free Metcon 3 combines the flexibilit...     0.0
# 6          0  Nike  Inspired by heritage models, the NikeCourt Bla...     0.0
# 7          0  Nike  The Nike Free Metcon 3 combines Nike Free flex...     5.0
# 8          0  Nike  The Nike Zoom Pegasus Turbo 2 is updated with ...     2.7
# 9          0  Nike  The Nike Air Max 270 React ENG combines a full...     5.0
# 10         0  Nike  Clean lines, versatile and timeless—the people...     5.0
# 11         0  Nike  The radiance lives on in the Nike Air Force 1 ...     4.5
# 12         0  Nike  With design inspiration taken from the iconic ...     0.0
# 13         0  Nike  The Nike SuperRep Go combines comfortable foam...     0.0
# 14         0  Nike  Be bouncy and buoyant in the Nike Air VaporMax...     4.4
# 15         0  Nike  The Nike Air Zoom SuperRep is designed for cir...     4.4
# 16         0  Nike  Refresh your step in the Nike Air Max 270 Reac...     0.0
# 17         0  Nike  The Nike Air Max 97 keeps a sneaker icon going...     4.3
# 18         0  Nike  The legend lives on in the Nike Air Force 1 '0...     0.0
# 19         0  Nike  The Nike Court Vintage Premium embodies '80s t...     0.0
#
#     reviews                                             images
# 0         0  ["https://static.nike.com/a/images/t_PDP_1728_...
# 1         0  ["https://static.nike.com/a/images/t_PDP_1728_...
# 2         0  ["https://static.nike.com/a/images/t_PDP_1728_...
# 3         0  ["https://static.nike.com/a/images/t_PDP_1728_...
# 4         0  ["https://static.nike.com/a/images/t_PDP_1728_...
# 5         0  ["https://static.nike.com/a/images/t_PDP_1728_...
# 6         0  ["https://static.nike.com/a/images/t_PDP_1728_...
# 7         1                                                NaN
# 8        14  ["https://static.nike.com/a/images/t_PDP_1728_...
# 9         2  ["https://static.nike.com/a/images/t_PDP_1728_...
# 10        9  ["https://static.nike.com/a/images/t_PDP_1728_...
# 11       67  ["https://static.nike.com/a/images/t_PDP_1728_...
# 12        0  ["https://static.nike.com/a/images/t_PDP_1728_...
# 13        0  ["https://static.nike.com/a/images/t_PDP_1728_...
# 14       48  ["https://static.nike.com/a/images/t_PDP_1728_...
# 15       34  ["https://static.nike.com/a/images/t_PDP_1728_...
# 16        0  ["https://static.nike.com/a/images/t_PDP_1728_...
# 17       16  ["https://static.nike.com/a/images/t_PDP_1728_...
# 18        0  ["https://static.nike.com/a/images/t_PDP_1728_...
# 19        0  ["https://static.nike.com/a/images/t_PDP_1728_...

# %%
#Cleaning the Dataframe
#Dropping unneeded columns
nikeCleaned = nikeSet.drop(['description','images','discount'], axis=1)

#converting prices into decimals
nikeCleaned['listing_price'] = nikeCleaned['listing_price'] / 100
nikeCleaned['sale_price'] = nikeCleaned['sale_price'] / 100

#Only want to look at shoes with active ratings/reviews
nike = nikeCleaned[nikeCleaned['reviews'] != 0]

#update the new index
nikeClean = nike.reset_index(drop=True)

nikeClean.head()
# Out:
#                  product_name  product_id  listing_price  sale_price brand  \
# 0          Nike Free Metcon 3  CJ0861-017            0.0       99.95  Nike
# 1   Nike Zoom Pegasus Turbo 2  AT8242-009            0.0      159.95  Nike
# 2  Nike Air Max 270 React ENG  CK2595-500            0.0      149.95  Nike
# 3             Nike Air Max 90  CD0490-104            0.0       99.95  Nike
# 4        Nike Air Force 1 '07  315115-112            0.0       74.95  Nike
#
#    rating  reviews
# 0     5.0        1
# 1     2.7       14
# 2     5.0        2
# 3     5.0        9
# 4     4.5       67

# %%
#Start looking for patterns
nikeClean.describe()
# Out:
#        listing_price  sale_price      rating     reviews
# count     414.000000  414.000000  414.000000  414.000000
# mean       43.971618  104.292512    4.247585   11.154589
# std        61.127003   42.602259    0.814179   18.760379
# min         0.000000   15.950000    1.000000    1.000000
# 25%         0.000000   71.970000    3.900000    2.000000
# 50%         0.000000   99.950000    4.400000    5.000000
# 75%        99.950000  129.950000    5.000000   12.750000
# max       189.950000  249.950000    5.000000  223.000000
